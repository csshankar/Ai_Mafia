# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('seaborn')

# %%
df = pd.read_csv('Week 2 Linear and Logistic Regression/Linear Regression/Assignment 2/Training Data/Train.csv')
dt = pd.read_csv('Week 2 Linear and Logistic Regression/Linear Regression/Assignment 2/Testing Data/Test.csv')

x = df.values
t = dt.values

m = x.shape
print(m,type(m))

#print(x[:,0])
#print('t',t)
#print(x)
target= x[:,5]
x=x[:, 0:5]


print(target)
df.head()
# Out:
# (1600, 6) <class 'tuple'>
# [ -82.15466656  -48.89796018   77.2703707  ... -107.51050797  -47.34155781
#  -115.93900296]
#    feature_1  feature_2  feature_3  feature_4  feature_5     target
# 0   0.293416  -0.945599  -0.421105   0.406816   0.525662 -82.154667
# 1  -0.836084  -0.189228  -0.776403  -1.053831   0.597997 -48.897960
# 2   0.236425   0.132836  -0.147723   0.699854  -0.187364  77.270371
# 3   0.175312   0.143194  -0.581111  -0.122107  -1.292168  -2.988581
# 4  -1.693011   0.542712  -2.798729  -0.686723   1.244077 -37.596722

# %%
#plotting data

plt.figure(0)
plt.scatter(x[:,0],target,label = 'feature_1',c='m')
plt.scatter(x[:,1],target,label = 'feature_2',c='g')
plt.scatter(x[:,2],target,label = 'feature_3',c='b')
plt.scatter(x[:,3],target,label = 'feature_4',c='k')
plt.scatter(x[:,4],target,label = 'feature_5',c='r')
#plt.scatter(target,target,label = 'result',c='r',marker='^')
plt.xlim(-3.8,3.8)
plt.ylim(-400,400)
plt.legend()
plt.show()

# %%
#impporting Linear Regression from scikit learn libraries
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression?

# %%
model = LinearRegression()

# %%
model.fit(x,target)
# Out:
# LinearRegression()

# %%
t.size
#predicting the value for test data
object = model.predict(t)

# %%
object= object.reshape(-1,1)
print(object)
# Out:
# [[ 1.14583689e+02]
#  [ 1.18012815e+02]
#  [-2.17398523e+01]
#  [-4.39368985e+01]
#  [-9.59148984e+01]
#  [-4.45074240e+01]
#  [-7.55665260e+01]
#  [ 2.38208355e+01]
#  [ 1.73835284e+02]
#  [ 1.72849290e+02]
#  [-1.05402312e+02]
#  [-2.08020234e+01]
#  [-3.91323777e+00]
#  [ 1.22999186e+02]
#  [ 4.03078842e+01]
#  [ 4.57128495e+01]
#  [-1.89628491e+02]
#  [ 2.26125454e+01]
#  [ 1.16410473e+01]
#  [ 1.36342143e+02]
#  [ 6.49162552e+01]
#  [-6.19884884e+01]
#  [-1.08194679e+02]
#  [-7.41212747e+00]
#  [-5.85239528e+01]
#  [ 1.18889777e+01]
#  [ 2.92376400e+01]
#  [ 1.07687579e+02]
#  [ 2.41468563e+01]
#  [-2.61050120e+01]
#  [ 1.10968076e+02]
#  [-4.48797096e+01]
#  [ 2.16799939e+02]
#  [-1.38606052e+01]
#  [-2.28603182e+02]
#  [ 1.54896021e+02]
#  [-2.22583390e+00]
#  [ 1.27230344e+01]
#  [-3.08307877e+02]
#  [ 7.71107583e+01]
#  [-8.12079177e+01]
#  [-2.06632925e+02]
#  [-2.38762881e+02]
#  [ 1.34757365e+02]
#  [-7.37514777e+01]
#  [ 1.05463702e+02]
#  [-3.59074927e+00]
# ...

# %%
#printing the intercepts and coefficients
print('Intercept: \n',model.intercept_)
print('Coefficients: \n', model.coef_ )
# Out:
# Intercept:
#  4.990966735574959
# Coefficients:
#  [29.68187118 92.66247759  8.28062089 44.76773522  2.51916121]
